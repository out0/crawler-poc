# %%
import cv2
import sys, math
from matplotlib import pyplot as plt
sys.path.append("..")

# %%
img = cv2.imread("../results/planning/plan_outp_0.png")

img[22,212,:] = [0,0,0]

# %%
plt.imshow(img)

# %%
def euclidian_distance(x1: float, y1: float, x2: float, y2: float) -> float:
    dx = x2 - x1
    dy = y2 - y1
    return math.sqrt(dx*dx + dy*dy)

# %%
euclidian_distance(32.9921989440918, -0.06747330725193024, 62.97111129760742, 1.1987580060958862)
# Out:
# 30.005641596850985
